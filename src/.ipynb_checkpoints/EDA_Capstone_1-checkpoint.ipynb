# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import missingno as msno
import seaborn as sns
from sklearn.linear_model import LinearRegression, LassoCV, Lasso
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler
from sklearn.base import clone
import matplotlib as mpl
mpl.rcParams.update({
    'figure.figsize'      : (15,15),
    'font.size'           : 20.0,
    'axes.titlesize'      : 'large',
    'axes.labelsize'      : 'medium',
    'xtick.labelsize'     : 'medium',
    'ytick.labelsize'     : 'medium',
    'legend.fontsize'     : 'large',
    'legend.loc'          : 'upper right'
})

# %%
df = pd.read_csv('../data/PIRUS.csv',na_values=['-99'])
# df = pd.read_csv('PIRUS.csv')

# %%
df.info()
df.head()
df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1865 entries, 0 to 1864
# Columns: 145 entries, Subject_ID to Standing
# dtypes: float64(112), int64(14), object(19)
# memory usage: 2.1+ MB
# Subject_ID                             0
# Loc_Plot_State1                       26
# Loc_Plot_City1                       286
# Loc_Plot_State2                     1618
# Loc_Plot_City2                      1686
# Date_Exposure                          0
# Plot_Target1                          33
# Plot_Target2                        1636
# Plot_Target3                        1781
# Attack_Preparation                   198
# Op_Security                          405
# Changing_Target                      349
# Anticp_Fatals_Targ                   225
# Internet_Use_Plot                    310
# Extent_Plot                           27
# Violent                                0
# Criminal_Severity                     18
# Criminal_Charges                      82
# Indict_Arrest                         41
# Current_Status                       271
# Group_Membership                       0
# Terrorist_Group_Name1                 18
# Terrorist_Group_Name2               1773
# Terrorist_Group_Name3               1852
# Actively_Recruited                  1004
# Recruiter1                          1017
# Recruiter2                          1851
# Recruiter3                          1864
# Actively_Connect                    1066
# Group_Competition                    799
#                                     ...
# Close_Family                        1376
# Family_Religiosity                  1588
# Family_Ideology                     1478
# Family_Ideological_Level            1501
# Prison_Family_Friend                1489
# Crime_Family_Friend                 1421
# Radical_Friend                       783
# Radical_Family                      1218
# Radical_Signif_Other                1087
# Relationship_Troubles               1270
# Platonic_Troubles                   1288
# Unstructured_Time                   1114
# Friendship_Source1                  1229
# Friendship_Source2                  1734
# Friendship_Source3                  1838
# Kicked_Out                          1483
# Previous_Criminal_Activity           854
# Previous_Criminal_Activity_Type1     872
# Previous_Criminal_Activity_Type2    1053
# Previous_Criminal_Activity_Type3    1167
# Previous_Criminal_Activity_Age       887
# Gang                                  28
# Gang_Ideology                         30
# Gang_Age_Joined                       99
# Gang_Radicalize                       86
# Trauma                              1474
# Other_Ideologies                       0
# Angry_US                             749
# Group_Grievance                      800
# Standing                            1476
# Length: 145, dtype: int64

# %%
msno.matrix(df.iloc[:,:50])

# %%
msno.matrix(df.iloc[:,50:100])

# %%
msno.matrix(df.iloc[:,100:])

# %%
cols = ['Subject_ID','Current_Status','Clique_Connect','Prison_Radicalize','Diaspora_Ties','Aspirations','Standing']
lst = [df.columns.get_loc(col) for col in cols]
catagories = ['Management and Identification Variables','Plot and Consequences', 'Group Nature', 'Radicalization', \
              'Demographics', 'Socioeconomic Status', 'Personal']
start = 0
for chunk,name in zip(lst,catagories):
    col = df.iloc[:,start:chunk+1].info()
    start = chunk + 1
    print(name,'\n',col,'\n')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1865 entries, 0 to 1864
# Data columns (total 1 columns):
# Subject_ID    1865 non-null int64
# dtypes: int64(1)
# memory usage: 14.6 KB
# Management and Identification Variables
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1865 entries, 0 to 1864
# Data columns (total 19 columns):
# Loc_Plot_State1       1839 non-null object
# Loc_Plot_City1        1579 non-null object
# Loc_Plot_State2       247 non-null object
# Loc_Plot_City2        179 non-null object
# Date_Exposure         1865 non-null object
# Plot_Target1          1832 non-null float64
# Plot_Target2          229 non-null float64
# Plot_Target3          84 non-null float64
# Attack_Preparation    1667 non-null float64
# Op_Security           1460 non-null float64
# Changing_Target       1516 non-null float64
# Anticp_Fatals_Targ    1640 non-null float64
# Internet_Use_Plot     1555 non-null float64
# Extent_Plot           1838 non-null float64
# Violent               1865 non-null int64
# Criminal_Severity     1847 non-null float64
# Criminal_Charges      1783 non-null float64
# Indict_Arrest         1824 non-null float64
# Current_Status        1594 non-null float64
# dtypes: float64(13), int64(1), object(5)
# memory usage: 276.9+ KB
# Plot and Consequences
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1865 entries, 0 to 1864
# Data columns (total 15 columns):
# Group_Membership         1865 non-null int64
# Terrorist_Group_Name1    1847 non-null object
# Terrorist_Group_Name2    92 non-null object
# Terrorist_Group_Name3    13 non-null object
# Actively_Recruited       861 non-null float64
# Recruiter1               848 non-null float64
# Recruiter2               14 non-null float64
# Recruiter3               1 non-null float64
# Actively_Connect         799 non-null float64
# Group_Competition        1066 non-null float64
# Role_Group               1751 non-null float64
# Length_Group             871 non-null float64
# Clique                   1201 non-null float64
# Clique_Radicalize        991 non-null float64
# Clique_Connect           971 non-null float64
# dtypes: float64(11), int64(1), object(3)
# memory usage: 218.6+ KB
# Group Nature
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1865 entries, 0 to 1864
# Data columns (total 41 columns):
# Internet_Radicalization        1184 non-null float64
# Media_Radicalization           543 non-null float64
# Social_Media                   1560 non-null float64
# Social_Media_Frequency         1427 non-null float64
# Social_Media_Platform1         1552 non-null float64
# Social_Media_Platform2         122 non-null float64
# Social_Media_Platform3         50 non-null float64
# Social_Media_Activities1       1552 non-null float64
# Social_Media_Activities2       236 non-null float64
# Social_Media_Activities3       167 non-null float64
# Social_Media_Activities4       55 non-null float64
# Social_Media_Activities5       11 non-null float64
# Social_Media_Activities6       6 non-null float64
# Social_Media_Activities7       1 non-null float64
# Radicalization_Islamist        1865 non-null int64
# Radicalization_Far_Right       1865 non-null int64
# Radicalization_Far_Left        1865 non-null int64
# Radicalization_Single_Issue    1865 non-null int64
# Ideological_Sub_Category1      1865 non-null int64
# Ideological_Sub_Category2      199 non-null float64
# Ideological_Sub_Category3      24 non-null float64
# Loc_Habitation_State1          1690 non-null object
# Loc_Habitation_City1           935 non-null object
# Loc_Habitation_State2          130 non-null object
# Loc_Habitation_City2           84 non-null object
# Itinerant                      1019 non-null float64
# External_Rad                   1258 non-null float64
# Rad_duration                   780 non-null float64
# Radical_Behaviors              1805 non-null float64
# Radical_Beliefs                1672 non-null float64
# US_Govt_Leader                 1035 non-null float64
# Foreign_Govt_Leader            1029 non-null float64
# Event_Influence1               942 non-null float64
# Event_Influence2               38 non-null float64
# Event_Influence3               3 non-null float64
# Event_Influence4               1 non-null float64
# Beliefs_Trajectory             745 non-null float64
# Behaviors_Trajectory           817 non-null float64
# Radicalization_Sequence        980 non-null float64
# Radicalization_Place           660 non-null float64
# Prison_Radicalize              1104 non-null float64
# dtypes: float64(32), int64(5), object(4)
# memory usage: 597.5+ KB
# Radicalization
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1865 entries, 0 to 1864
# Data columns (total 19 columns):
# Broad_Ethnicity         1680 non-null float64
# Age                     1782 non-null float64
# Marital_Status          1077 non-null float64
# Children                940 non-null float64
# Age_Child               662 non-null float64
# Gender                  1865 non-null int64
# Religious_Background    712 non-null float64
# Convert                 631 non-null float64
# Convert_Date            565 non-null object
# Reawakening             442 non-null float64
# Reawakening_Date        425 non-null object
# Citizenship             1756 non-null object
# Residency_Status        1723 non-null float64
# Nativity                1751 non-null object
# Time_US_Months          1402 non-null float64
# Immigrant_Generation    1755 non-null float64
# Immigrant_Source        1697 non-null object
# Language_English        1677 non-null float64
# Diaspora_Ties           1512 non-null object
# dtypes: float64(12), int64(1), object(6)
# memory usage: 276.9+ KB
# Demographics
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1865 entries, 0 to 1864
# Data columns (total 11 columns):
# Education                   725 non-null float64
# Student                     1060 non-null float64
# Education_Change            864 non-null float64
# Employment_Status           854 non-null float64
# Change_Performance          404 non-null float64
# Work_History                817 non-null float64
# Military                    1203 non-null float64
# Foreign_Military            1442 non-null float64
# Social_Stratum_Childhood    436 non-null float64
# Social_Stratum_Adulthood    909 non-null float64
# Aspirations                 312 non-null float64
# dtypes: float64(11)
# memory usage: 160.4 KB
# Socioeconomic Status
#  None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1865 entries, 0 to 1864
# Data columns (total 39 columns):
# Abuse_Child                         1865 non-null int64
# Abuse_Adult                         1865 non-null int64
# Abuse_type1                         1854 non-null float64
# Abuse_Type2                         18 non-null float64
# Abuse_Type3                         2 non-null float64
# Psychological                       1865 non-null int64
# Alcohol_Drug                        1865 non-null int64
# Absent_Parent                       421 non-null float64
# Overseas_Family                     405 non-null float64
# Close_Family                        489 non-null float64
# Family_Religiosity                  277 non-null float64
# Family_Ideology                     387 non-null float64
# Family_Ideological_Level            364 non-null float64
# Prison_Family_Friend                376 non-null float64
# Crime_Family_Friend                 444 non-null float64
# Radical_Friend                      1082 non-null float64
# Radical_Family                      647 non-null float64
# Radical_Signif_Other                778 non-null float64
# Relationship_Troubles               595 non-null float64
# Platonic_Troubles                   577 non-null float64
# Unstructured_Time                   751 non-null float64
# Friendship_Source1                  636 non-null float64
# Friendship_Source2                  131 non-null float64
# Friendship_Source3                  27 non-null float64
# Kicked_Out                          382 non-null float64
# Previous_Criminal_Activity          1011 non-null float64
# Previous_Criminal_Activity_Type1    993 non-null float64
# Previous_Criminal_Activity_Type2    812 non-null float64
# Previous_Criminal_Activity_Type3    698 non-null float64
# Previous_Criminal_Activity_Age      978 non-null float64
# Gang                                1837 non-null float64
# Gang_Ideology                       1835 non-null float64
# Gang_Age_Joined                     1766 non-null object
# Gang_Radicalize                     1779 non-null float64
# Trauma                              391 non-null float64
# Other_Ideologies                    1865 non-null int64
# Angry_US                            1116 non-null float64
# Group_Grievance                     1065 non-null float64
# Standing                            389 non-null float64
# dtypes: float64(33), int64(5), object(1)
# memory usage: 568.3+ KB
# Personal
#  None

# %%
print(df.Violent.unique())
print(df.Violent.count())
print(df.Violent.sum())
print(df.Violent.sum()/df.Violent.count()*100)
# Out:
# [1 0]
# 1865
# 1100
# 58.98123324396782

# %%
df[df.Gender==1].Gender.count()
# Out:
# 182

# %%
columns = list(df.loc[:,'Broad_Ethnicity':'Aspirations'].columns)
columns.remove('Age_Child')
df.Language_English.replace({-88:1})
df.Gender.replace({1:0,2:1})
df[['Education_Change','Change_Performance','Work_History','Social_Stratum_Adulthood']].replace(-88,'NaN')
y = df['Violent']
X = df[columns].select_dtypes(exclude='object').fillna(df.mean())
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %%
corr = df[columns+['Violent']].corr()
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns)

# %%
import statsmodels.api as sm
import statsmodels.stats.outliers_influence as oi
from statsmodels.stats import diagnostic

linear_model = sm.OLS(y_train, X_train).fit()
print(linear_model.summary2())


for idx, col in enumerate(X.columns):

    print(f"{col}: {oi.variance_inflation_factor(X.values,idx)}")

print(diagnostic.het_goldfeldquandt(linear_model.resid, linear_model.model.exog))
# Out:
#                     Results: Ordinary least squares
# ========================================================================
# Model:                OLS                Adj. R-squared:       0.616
# Dependent Variable:   Violent            AIC:                  2293.2021
# Date:                 2018-10-11 22:15   BIC:                  2417.9854
# No. Observations:     1678               Log-Likelihood:       -1123.6
# Df Model:             23                 F-statistic:          118.1
# Df Residuals:         1655               Prob (F-statistic):   0.00
# R-squared:            0.621              Scale:                0.22653
# ------------------------------------------------------------------------
#                           Coef.  Std.Err.    t    P>|t|   [0.025  0.975]
# ------------------------------------------------------------------------
# Broad_Ethnicity          -0.0523   0.0146 -3.5903 0.0003 -0.0808 -0.0237
# Age                      -0.0042   0.0017 -2.3984 0.0166 -0.0076 -0.0008
# Marital_Status            0.0004   0.0247  0.0160 0.9872 -0.0481  0.0489
# Children                 -0.0171   0.0095 -1.7950 0.0728 -0.0358  0.0016
# Gender                    0.2724   0.0357  7.6324 0.0000  0.2024  0.3424
# Religious_Background     -0.0167   0.0045 -3.7272 0.0002 -0.0255 -0.0079
# Convert                   0.1004   0.0362  2.7760 0.0056  0.0295  0.1713
# Reawakening               0.0531   0.0400  1.3271 0.1846 -0.0254  0.1316
# Residency_Status          0.0536   0.0249  2.1509 0.0316  0.0047  0.1024
# Time_US_Months            0.0002   0.0001  1.6885 0.0915 -0.0000  0.0005
# Immigrant_Generation      0.1145   0.0306  3.7400 0.0002  0.0545  0.1746
# Language_English         -0.0010   0.0006 -1.8222 0.0686 -0.0022  0.0001
# Education                -0.0153   0.0082 -1.8580 0.0633 -0.0315  0.0009
# Student                  -0.0513   0.0476 -1.0778 0.2813 -0.1445  0.0420
# Education_Change         -0.0021   0.0008 -2.6055 0.0093 -0.0037 -0.0005
# Employment_Status        -0.0025   0.0155 -0.1627 0.8708 -0.0329  0.0279
# Change_Performance       -0.0020   0.0006 -3.0836 0.0021 -0.0032 -0.0007
# Work_History              0.0000   0.0009  0.0255 0.9796 -0.0017  0.0018
# Military                 -0.0033   0.0139 -0.2372 0.8125 -0.0306  0.0240
# Foreign_Military         -0.0531   0.1970 -0.2697 0.7874 -0.4395  0.3332
# Social_Stratum_Childhood  0.0340   0.0357  0.9530 0.3407 -0.0360  0.1039
# Social_Stratum_Adulthood  0.0012   0.0012  1.0202 0.3078 -0.0011  0.0035
# Aspirations              -0.0235   0.0254 -0.9255 0.3548 -0.0735  0.0264
# ------------------------------------------------------------------------
# Omnibus:                20.654         Durbin-Watson:            1.942
# Prob(Omnibus):          0.000          Jarque-Bera (JB):         194.461
# Skew:                   -0.275         Prob(JB):                 0.000
# Kurtosis:               1.426          Condition No.:            7334
# ========================================================================
# * The condition number is large (7e+03). This might indicate
# strong multicollinearity or other numerical problems.
# Broad_Ethnicity: 14.713402508635712
# Age: 28.77918691766456
# Marital_Status: 13.290326007716832
# Children: 2.1825843664215516
# Gender: 34.77917553407298
# Religious_Background: 10.159223713621895
# Convert: 2.180942837536818
# Reawakening: 1.8237632932097103
# Residency_Status: 8.423633171957986
# Time_US_Months: 26.56436342622314
# Immigrant_Generation: 2.0119896367542394
# Language_English: 16.716816900649977
# Education: 11.741855877542816
# Student: 2.7607918121118473
# Education_Change: 31.87132770663743
# Employment_Status: 10.130627035937394
# Change_Performance: 7.042457976895558
# Work_History: 2.027869223403352
# Military: 1.3058840510715743
# Foreign_Military: 1.0270202859680142
# Social_Stratum_Childhood: 34.253278888097
# Social_Stratum_Adulthood: 1.1057288286071842
# Aspirations: 8.59450891375994
# (0.9793511559614393, 0.6171171233171642, 'increasing')
